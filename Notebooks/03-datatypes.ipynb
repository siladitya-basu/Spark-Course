# %% [markdown]
# # Data Types

# %%
import pyspark
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *

from delta import *
import pandas as pd

# start spark
builder = (pyspark.sql.SparkSession.builder.appName("Spark-Course")
                .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
                .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog"))

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# setting log-level to ERROR to decrease verbosity
# log4j log-levels are: OFF, FATAL, ERROR, WARN, INFO, DEBUG, TRACE, ALL
spark.sparkContext.setLogLevel("ERROR")

spark
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/siladitya/.ivy2/cache
# The jars for the packages stored in: /home/siladitya/.ivy2/jars
# io.delta#delta-core_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-df4a3c30-57ad-47ae-9038-5bfc85ba4d8e;1.0
# 	confs: [default]
# 	found io.delta#delta-core_2.12;1.2.1 in central
# 	found io.delta#delta-storage;1.2.1 in central
# 	found org.antlr#antlr4-runtime;4.8 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# :: resolution report :: resolve 467ms :: artifacts dl 8ms
# 	:: modules in use:
# 	io.delta#delta-core_2.12;1.2.1 from central in [default]
# 	io.delta#delta-storage;1.2.1 from central in [default]
# 	org.antlr#antlr4-runtime;4.8 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   4   |   0   |   0   |   0   ||   4   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-df4a3c30-57ad-47ae-9038-5bfc85ba4d8e
# 	confs: [default]
# 	0 artifacts copied, 4 already retrieved (0kB/7ms)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.209:4043">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark-Course</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# so that Pandas df display all columns, default is 20
pd.set_option('display.max_columns', None)

# %%
# %load_ext sparksql_magic

# %%
# pretty display function
def display(spark_df, rows=10):
    return spark_df.limit(rows).toPandas().head(rows)

# %%
raw_data_path = '/home/siladitya/Documents/Spark/Spark-Course/Data/imdb/'

title_basics_schema = StructType([
                            StructField('tconst', StringType(), False),
                            StructField('titleType', StringType(), True),
                            StructField('primaryTitle', StringType(), True),
                            StructField('originalTitle', StringType(), True),
                            StructField('isAdult', IntegerType(), True),
                            StructField('startYear', IntegerType(), True),
                            StructField('endYear', IntegerType(), True),
                            StructField('runtimeMinutes', IntegerType(), True),
                            StructField('genres', StringType(), True)])

title_basics_sdf = (spark
                    .read
                    .schema(title_basics_schema)
                    .option('header', 'true')
                    .option('delimiter', '\t')
                    .csv(raw_data_path + 'title_basics.tsv'))

title_basics_sdf.createOrReplaceTempView('titles')

display(title_basics_sdf)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     short                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 0                                   Carmencita        0       1894      NaN
# 1                       Le clown et ses chiens        0       1892      NaN
# 2                               Pauvre Pierrot        0       1892      NaN
# 3                                  Un bon bock        0       1892      NaN
# 4                             Blacksmith Scene        0       1893      NaN
# 5                            Chinese Opium Den        0       1894      NaN
# 6  Corbett and Courtney Before the Kinetograph        0       1894      NaN
# 7       Edison Kinetoscopic Record of a Sneeze        0       1894      NaN
# 8                                   Miss Jerry        0       1894      NaN
# 9          La sortie de l'usine Lumière à Lyon        0       1895      NaN
#
#    runtimeMinutes                    genres
# 0               1         Documentary,Short
# 1               5           Animation,Short
# 2               4  Animation,Comedy,Romance
# 3              12           Animation,Short
# 4               1              Comedy,Short
# 5               1                     Short
# 6               1               Short,Sport
# 7               1         Documentary,Short
# 8              40             Romance,Short
# 9               1         Documentary,Short

# %%
title_basics_sdf.printSchema()
# Out:
# root
#  |-- tconst: string (nullable = true)
#  |-- titleType: string (nullable = true)
#  |-- primaryTitle: string (nullable = true)
#  |-- originalTitle: string (nullable = true)
#  |-- isAdult: integer (nullable = true)
#  |-- startYear: integer (nullable = true)
#  |-- endYear: integer (nullable = true)
#  |-- runtimeMinutes: integer (nullable = true)
#  |-- genres: string (nullable = true)

# %% [markdown]
# ### Booleans
# Filtering statements.

# %%
nineteenth_century = col('startYear') < 1900

display(
    title_basics_sdf
        .where(nineteenth_century)
)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     short                                   Miss Jerry
# 9  tt0000010     short                          Leaving the Factory
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 0                                   Carmencita        0       1894      NaN
# 1                       Le clown et ses chiens        0       1892      NaN
# 2                               Pauvre Pierrot        0       1892      NaN
# 3                                  Un bon bock        0       1892      NaN
# 4                             Blacksmith Scene        0       1893      NaN
# 5                            Chinese Opium Den        0       1894      NaN
# 6  Corbett and Courtney Before the Kinetograph        0       1894      NaN
# 7       Edison Kinetoscopic Record of a Sneeze        0       1894      NaN
# 8                                   Miss Jerry        0       1894      NaN
# 9          La sortie de l'usine Lumière à Lyon        0       1895      NaN
#
#    runtimeMinutes                    genres
# 0               1         Documentary,Short
# 1               5           Animation,Short
# 2               4  Animation,Comedy,Romance
# 3              12           Animation,Short
# 4               1              Comedy,Short
# 5               1                     Short
# 6               1               Short,Sport
# 7               1         Documentary,Short
# 8              40             Romance,Short
# 9               1         Documentary,Short

# %%
display(
    title_basics_sdf
        .where('startYear < 1900') # didn't use col()
        .where(instr(col('genres'), 'Animation') >= 1)
)
# Out:
#        tconst titleType                                       primaryTitle  \
# 0   tt0000002     short                             Le clown et ses chiens
# 1   tt0000003     short                                     Pauvre Pierrot
# 2   tt0000004     short                                        Un bon bock
# 3   tt0000015     short                                Autour d'une cabine
# 4   tt0000233     short                      Choque de dos transatlánticos
# 5   tt0000251     short                                 Matches: An Appeal
# 6   tt0000704     short                           The Humpty Dumpty Circus
# 7   tt0337350     short                        Two Tipsy Fellows in a Boat
# 8  tt12592084     short                                  Le singe musicien
# 9  tt13125956     short  Autour d'une cabine ou Mésaventures d'un copur...
#
#                                        originalTitle  isAdult  startYear  \
# 0                             Le clown et ses chiens        0       1892
# 1                                     Pauvre Pierrot        0       1892
# 2                                        Un bon bock        0       1892
# 3                                Autour d'une cabine        0       1894
# 4                      Choque de dos transatlánticos        0       1899
# 5                                 Matches: An Appeal        0       1899
# 6                           The Humpty Dumpty Circus        0       1898
# 7                        Two Tipsy Fellows in a Boat        0       1898
# 8                                  Le singe musicien        0       1878
# 9  Autour d'une cabine ou Mésaventures d'un copur...        0       1894
#
#    endYear  runtimeMinutes                    genres
# 0      NaN             5.0           Animation,Short
# 1      NaN             4.0  Animation,Comedy,Romance
# 2      NaN            12.0           Animation,Short
# 3      NaN             2.0           Animation,Short
# 4      NaN             2.0           Animation,Short
# 5      NaN             1.0           Animation,Short
# 6      NaN             NaN    Animation,Comedy,Short
# 7      NaN             NaN    Animation,Comedy,Short
# 8      NaN             1.0           Animation,Short
# 9      NaN             5.0           Animation,Short

# %%
# %%sparksql
# select * from titles
# where startYear < 1900 and instr(genres, 'Animation') >= 1
# limit 10
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">tconst</td><td style="font-weight: bold">titleType</td><td style="font-weight: bold">primaryTitle</td><td style="font-weight: bold">originalTitle</td><td style="font-weight: bold">isAdult</td><td style="font-weight: bold">startYear</td><td style="font-weight: bold">endYear</td><td style="font-weight: bold">runtimeMinutes</td><td style="font-weight: bold">genres</td></tr><tr><td>tt0000002</td><td>short</td><td>Le clown et ses chiens</td><td>Le clown et ses chiens</td><td>0</td><td>1892</td><td>null</td><td>5</td><td>Animation,Short</td></tr><tr><td>tt0000003</td><td>short</td><td>Pauvre Pierrot</td><td>Pauvre Pierrot</td><td>0</td><td>1892</td><td>null</td><td>4</td><td>Animation,Comedy,Romance</td></tr><tr><td>tt0000004</td><td>short</td><td>Un bon bock</td><td>Un bon bock</td><td>0</td><td>1892</td><td>null</td><td>12</td><td>Animation,Short</td></tr><tr><td>tt0000015</td><td>short</td><td>Autour d&#x27;une cabine</td><td>Autour d&#x27;une cabine</td><td>0</td><td>1894</td><td>null</td><td>2</td><td>Animation,Short</td></tr><tr><td>tt0000233</td><td>short</td><td>Choque de dos transatlánticos</td><td>Choque de dos transatlánticos</td><td>0</td><td>1899</td><td>null</td><td>2</td><td>Animation,Short</td></tr><tr><td>tt0000251</td><td>short</td><td>Matches: An Appeal</td><td>Matches: An Appeal</td><td>0</td><td>1899</td><td>null</td><td>1</td><td>Animation,Short</td></tr><tr><td>tt0000704</td><td>short</td><td>The Humpty Dumpty Circus</td><td>The Humpty Dumpty Circus</td><td>0</td><td>1898</td><td>null</td><td>null</td><td>Animation,Comedy,Short</td></tr><tr><td>tt0337350</td><td>short</td><td>Two Tipsy Fellows in a Boat</td><td>Two Tipsy Fellows in a Boat</td><td>0</td><td>1898</td><td>null</td><td>null</td><td>Animation,Comedy,Short</td></tr><tr><td>tt12592084</td><td>short</td><td>Le singe musicien</td><td>Le singe musicien</td><td>0</td><td>1878</td><td>null</td><td>1</td><td>Animation,Short</td></tr><tr><td>tt13125956</td><td>short</td><td>Autour d&#x27;une cabine ou Mésaventures d&#x27;un copurchic aux bains de mer</td><td>Autour d&#x27;une cabine ou Mésaventures d&#x27;un copurchic aux bains de mer</td><td>0</td><td>1894</td><td>null</td><td>5</td><td>Animation,Short</td></tr></table>

# %%
# null-safe comparison
display(
    title_basics_sdf
.   where(col('endYear').eqNullSafe(2000))
)
# Out:
#       tconst titleType                      primaryTitle  \
# 0  tt0087305  tvSeries               The Power of Desire
# 1  tt0090405  tvSeries    The Bugs Bunny and Tweety Show
# 2  tt0092379  tvSeries                   Inspector Morse
# 3  tt0098749  tvSeries              Beverly Hills, 90210
# 4  tt0103352  tvSeries       Are You Afraid of the Dark?
# 5  tt0103375  tvSeries     Both Sides with Jesse Jackson
# 6  tt0103556  tvSeries                       Stadtklinik
# 7  tt0105958  tvSeries                   Boy Meets World
# 8  tt0106123  tvSeries  Saved by the Bell: The New Class
# 9  tt0108724  tvSeries                      Chicago Hope
#
#                       originalTitle  isAdult  startYear  endYear  \
# 0                Força de Um Desejo        0       1999     2000
# 1    The Bugs Bunny and Tweety Show        0       1986     2000
# 2                   Inspector Morse        0       1987     2000
# 3              Beverly Hills, 90210        0       1990     2000
# 4       Are You Afraid of the Dark?        0       1990     2000
# 5     Both Sides with Jesse Jackson        0       1992     2000
# 6                       Stadtklinik        0       1993     2000
# 7                   Boy Meets World        0       1993     2000
# 8  Saved by the Bell: The New Class        0       1993     2000
# 9                      Chicago Hope        0       1994     2000
#
#    runtimeMinutes                   genres
# 0            45.0            Drama,Romance
# 1             NaN  Animation,Comedy,Family
# 2           100.0      Crime,Drama,Mystery
# 3            44.0            Drama,Romance
# 4            30.0     Drama,Fantasy,Horror
# 5            30.0                Talk-Show
# 6            74.0                    Drama
# 7            23.0      Comedy,Drama,Family
# 8            30.0            Comedy,Family
# 9            60.0   Drama,Mystery,Thriller

# %% [markdown]
# ### Numbers

# %%
# Pearson correlation
display(
    title_basics_sdf
        .select(corr('startYear', 'runtimeMinutes'))
)
# Out:
#    corr(startYear, runtimeMinutes)
# 0                        -0.056034

# %%
display(
    title_basics_sdf
        .select('startYear', 'genres')
        .describe()
)
# Out:
#   summary           startYear   genres
# 0   count             7696751  8880191
# 1    mean  2004.2420261484358     None
# 2  stddev  20.333056646472354     None
# 3     min                1874   Action
# 4     max                2029       \N

# %%
(title_basics_sdf
    .approxQuantile('runtimeMinutes',
                    probabilities= [0.5],
                    relativeError= 0.05))
# Out:
# [30.0]

# %%
display(
    title_basics_sdf
        # .limit(10000)
        .crosstab('genres', 'isAdult')
)
# Out:
#              genres_isAdult     0  1  1981  2005  2014  2017  2019  2020  null
# 0      Action,Adult,Romance     0  8     0     0     0     0     0     0     0
# 1   Documentary,Horror,News    54  0     0     0     0     0     0     0     0
# 2      Action,Music,Western    17  0     0     0     0     0     0     0     0
# 3  Animation,Family,Fantasy  4620  0     0     0     0     0     0     0     0
# 4     Crime,Musical,Romance    16  0     0     0     0     0     0     0     0
# 5         Action,Drama,News     6  0     0     0     0     0     0     0     0
# 6         Romance,Talk-Show    30  0     0     0     0     0     0     0     0
# 7     Biography,News,Sci-Fi     1  0     0     0     0     0     0     0     0
# 8     Drama,Musical,Western     8  0     0     0     0     0     0     0     0
# 9            Family,Romance  1459  0     0     0     0     0     0     0     0

# %%
display(
    title_basics_sdf
        # .limit(1000)
        .freqItems(['genres', 'isAdult'])
)
# Out:
#                                     genres_freqItems  \
# 0  [Action, News,Talk-Show, Action,Adventure,Come...
#
#                                   isAdult_freqItems
# 0  [2017, 2020, 2005, 2014, 1981, 1, 2019, None, 0]

# %% [markdown]
# ### Strings

# %%
# character-level replacement
# 'a' -> '4'
# 'e' -> '3'
# 's' -> '5'
# 't' -> ''
display(
    title_basics_sdf
        .select(translate('primaryTitle', 'aest', '435'), 'primaryTitle')
)
# Out:
#        translate(primaryTitle, aest, 435)  \
# 0                               C4rm3nci4
# 1                   L3 clown 3 535 chi3n5
# 2                           P4uvr3 Pi3rro
# 3                             Un bon bock
# 4                         Bl4ck5mih Sc3n3
# 5                       Chin353 Opium D3n
# 6  Corb3 4nd Courn3y B3for3 h3 Kin3ogr4ph
# 7   Edi5on Kin3o5copic R3cord of 4 Sn33z3
# 8                              Mi55 J3rry
# 9                       L34ving h3 F4cory
#
#                                   primaryTitle
# 0                                   Carmencita
# 1                       Le clown et ses chiens
# 2                               Pauvre Pierrot
# 3                                  Un bon bock
# 4                             Blacksmith Scene
# 5                            Chinese Opium Den
# 6  Corbett and Courtney Before the Kinetograph
# 7       Edison Kinetoscopic Record of a Sneeze
# 8                                   Miss Jerry
# 9                          Leaving the Factory

# %%
display(
    title_basics_sdf
        .select(regexp_replace('genres', 'Documentary|Sport|Animation|Comedy|Romance', '---'), 'genres')
)
# Out:
#   regexp_replace(genres, Documentary|Sport|Animation|Comedy|Romance, ---, 1)  \
# 0                                          ---,Short
# 1                                          ---,Short
# 2                                        ---,---,---
# 3                                          ---,Short
# 4                                          ---,Short
# 5                                              Short
# 6                                          Short,---
# 7                                          ---,Short
# 8                                          ---,Short
# 9                                          ---,Short
#
#                      genres
# 0         Documentary,Short
# 1           Animation,Short
# 2  Animation,Comedy,Romance
# 3           Animation,Short
# 4              Comedy,Short
# 5                     Short
# 6               Short,Sport
# 7         Documentary,Short
# 8             Romance,Short
# 9         Documentary,Short

# %%
# %%sparksql
# select regexp_extract(genres, '(Documentary|Sport|Animation|Comedy|Romance)'), genres from titles limit 10
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">regexp_extract(genres, (Documentary|Sport|Animation|Comedy|Romance), 1)</td><td style="font-weight: bold">genres</td></tr><tr><td>Documentary</td><td>Documentary,Short</td></tr><tr><td>Animation</td><td>Animation,Short</td></tr><tr><td>Animation</td><td>Animation,Comedy,Romance</td></tr><tr><td>Animation</td><td>Animation,Short</td></tr><tr><td>Comedy</td><td>Comedy,Short</td></tr><tr><td></td><td>Short</td></tr><tr><td>Sport</td><td>Short,Sport</td></tr><tr><td>Documentary</td><td>Documentary,Short</td></tr><tr><td>Romance</td><td>Romance,Short</td></tr><tr><td>Documentary</td><td>Documentary,Short</td></tr></table>

# %% [markdown]
# ##### Locate

# %%
genre_list = ['Documentary','Sport','Animation','Comedy','Romance']
is_genre_cols = [locate(g, 'genres').alias('is_' + g) for g in genre_list]
is_genre_cols
# Out:
# [Column<'locate(Documentary, genres, 1) AS is_Documentary'>,
#  Column<'locate(Sport, genres, 1) AS is_Sport'>,
#  Column<'locate(Animation, genres, 1) AS is_Animation'>,
#  Column<'locate(Comedy, genres, 1) AS is_Comedy'>,
#  Column<'locate(Romance, genres, 1) AS is_Romance'>]

# %%
is_genre_cols.append(expr('*'))

display(
    title_basics_sdf
        .select(*is_genre_cols)
)
# Out:
#    is_Documentary  is_Sport  is_Animation  is_Comedy  is_Romance     tconst  \
# 0               1         0             0          0           0  tt0000001
# 1               0         0             1          0           0  tt0000002
# 2               0         0             1         11          18  tt0000003
# 3               0         0             1          0           0  tt0000004
# 4               0         0             0          1           0  tt0000005
# 5               0         0             0          0           0  tt0000006
# 6               0         7             0          0           0  tt0000007
# 7               1         0             0          0           0  tt0000008
# 8               0         0             0          0           1  tt0000009
# 9               1         0             0          0           0  tt0000010
#
#   titleType                                 primaryTitle  \
# 0     short                                   Carmencita
# 1     short                       Le clown et ses chiens
# 2     short                               Pauvre Pierrot
# 3     short                                  Un bon bock
# 4     short                             Blacksmith Scene
# 5     short                            Chinese Opium Den
# 6     short  Corbett and Courtney Before the Kinetograph
# 7     short       Edison Kinetoscopic Record of a Sneeze
# 8     short                                   Miss Jerry
# 9     short                          Leaving the Factory
#
#                                  originalTitle  isAdult  startYear  endYear  \
# 0                                   Carmencita        0       1894      NaN
# 1                       Le clown et ses chiens        0       1892      NaN
# 2                               Pauvre Pierrot        0       1892      NaN
# 3                                  Un bon bock        0       1892      NaN
# 4                             Blacksmith Scene        0       1893      NaN
# 5                            Chinese Opium Den        0       1894      NaN
# 6  Corbett and Courtney Before the Kinetograph        0       1894      NaN
# 7       Edison Kinetoscopic Record of a Sneeze        0       1894      NaN
# 8                                   Miss Jerry        0       1894      NaN
# 9          La sortie de l'usine Lumière à Lyon        0       1895      NaN
#
#    runtimeMinutes                    genres
# 0               1         Documentary,Short
# 1               5           Animation,Short
# 2               4  Animation,Comedy,Romance
# 3              12           Animation,Short
# 4               1              Comedy,Short
# 5               1                     Short
# 6               1               Short,Sport
# 7               1         Documentary,Short
# 8              40             Romance,Short
# 9               1         Documentary,Short

# %%
is_genre_cols_boolean = [locate(g, 'genres').cast('Boolean').cast('Integer').alias('is_' + g) for g in genre_list]
is_genre_cols_boolean.append(expr('*'))

display(
    title_basics_sdf
        .select(*is_genre_cols_boolean)
        .where('is_Documentary + is_Sport + is_Animation + is_Comedy + is_Romance >= 3') # at least 3 genres
)
# Out:
#    is_Documentary  is_Sport  is_Animation  is_Comedy  is_Romance     tconst  \
# 0               0         0             1          1           1  tt0000003
# 1               0         0             1          1           1  tt0006533
# 2               0         1             0          1           1  tt0014578
# 3               0         1             0          1           1  tt0016226
# 4               0         1             0          1           1  tt0016423
# 5               0         0             1          1           1  tt0016587
# 6               0         0             1          1           1  tt0016790
# 7               0         1             0          1           1  tt0016844
# 8               0         1             0          1           1  tt0016994
# 9               0         1             0          1           1  tt0018267
#
#   titleType                    primaryTitle                   originalTitle  \
# 0     short                  Pauvre Pierrot                  Pauvre Pierrot
# 1     short  Colonel Heeza Liar's Courtship  Colonel Heeza Liar's Courtship
# 2     movie                      The Victor                      The Victor
# 3     movie                 The Plastic Age                 The Plastic Age
# 4     movie                The Thoroughbred                The Thoroughbred
# 5     short          Alice the Fire Fighter          Alice the Fire Fighter
# 6     short           Dinky Doodle in Egypt           Dinky Doodle in Egypt
# 7     movie               Fascinating Youth               Fascinating Youth
# 8     movie              In Borrowed Plumes              In Borrowed Plumes
# 9     movie        Pleasure Before Business        Pleasure Before Business
#
#    isAdult  startYear  endYear  runtimeMinutes                    genres
# 0        0       1892      NaN             4.0  Animation,Comedy,Romance
# 1        0       1916      NaN             NaN  Animation,Comedy,Romance
# 2        0       1923      NaN            50.0      Comedy,Romance,Sport
# 3        0       1925      NaN            73.0      Comedy,Romance,Sport
# 4        0       1925      NaN            63.0      Comedy,Romance,Sport
# 5        0       1926      NaN             9.0  Animation,Comedy,Romance
# 6        0       1926      NaN             8.0  Animation,Comedy,Romance
# 7        0       1926      NaN            70.0      Comedy,Romance,Sport
# 8        0       1926      NaN            60.0      Comedy,Romance,Sport
# 9        0       1927      NaN            55.0      Comedy,Romance,Sport

# %% [markdown]
# ### Nulls

# %%
# %%sparksql
# select
#     ifnull(null, 'value'),
#     nullif('value', 'value'),
#     nvl(null, 'value'),
#     nvl2('not_null', 'first_value', 'second_value'),
#     nvl2(null, 'first_value', 'second_value')
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">ifnull(NULL, value)</td><td style="font-weight: bold">nullif(value, value)</td><td style="font-weight: bold">nvl(NULL, value)</td><td style="font-weight: bold">nvl2(not_null, first_value, second_value)</td><td style="font-weight: bold">nvl2(NULL, first_value, second_value)</td></tr><tr><td>value</td><td>null</td><td>value</td><td>first_value</td><td>second_value</td></tr></table>

# %%
# %%sparksql
# select primaryTitle, coalesce(startYear, endYear)
# from titles
# limit 5
# Out:
# <table><tr style="border-bottom: 1px solid"><td style="font-weight: bold">primaryTitle</td><td style="font-weight: bold">coalesce(startYear, endYear)</td></tr><tr><td>Carmencita</td><td>1894</td></tr><tr><td>Le clown et ses chiens</td><td>1892</td></tr><tr><td>Pauvre Pierrot</td><td>1892</td></tr><tr><td>Un bon bock</td><td>1892</td></tr><tr><td>Blacksmith Scene</td><td>1893</td></tr></table>

# %%
display(
    spark.createDataFrame([Row(None, None, None),
                            Row(1, 2, None),
                            Row(None, None, 3)])
)
# Out:
#     _1   _2   _3
# 0  NaN  NaN  NaN
# 1  1.0  2.0  NaN
# 2  NaN  NaN  3.0

# %%
# drop row if any value is null
display(
    spark.createDataFrame([Row(None, None, None),
                            Row(1, 2, None),
                            Row(None, None, 3)])
        .na.drop('any')
)
# Out:
# Empty DataFrame
# Columns: [_1, _2, _3]
# Index: []

# %%
#  drop row where all are nulls
display(
    spark.createDataFrame([Row(None, None, None),
                            Row(1, 2, None),
                            Row(None, None, 3)])
        .na.drop('all')
)
# Out:
#     _1   _2   _3
# 0  1.0  2.0  NaN
# 1  NaN  NaN  3.0

# %%
#  drop if all cols in the subset are null
display(
    spark.createDataFrame([Row(None, None, None),
                            Row(1, 2, None),
                            Row(None, None, 3)])
        .na.drop('all', subset=['_1', '_2'])
)
# Out:
#    _1  _2  _3
# 0   1   2 NaN

# %%
display(
    spark.createDataFrame([Row(None, None, None),
                            Row(1, 2, None),
                            Row(None, None, 3)])
        .na.fill(0, subset=['_1', '_2'])
)
# Out:
#    _1  _2   _3
# 0   0   0  NaN
# 1   1   2  NaN
# 2   0   0  3.0

# %% [markdown]
# ### Structs
# Dataframe within a dataframe.

# %%
struct_df = (
    title_basics_sdf
        .selectExpr('primaryTitle', 'struct(runtimeMinutes, startYear, genres) as movie')
)

display(struct_df)
# Out:
#                                   primaryTitle  \
# 0                                   Carmencita
# 1                       Le clown et ses chiens
# 2                               Pauvre Pierrot
# 3                                  Un bon bock
# 4                             Blacksmith Scene
# 5                            Chinese Opium Den
# 6  Corbett and Courtney Before the Kinetograph
# 7       Edison Kinetoscopic Record of a Sneeze
# 8                                   Miss Jerry
# 9                          Leaving the Factory
#
#                                  movie
# 0         (1, 1894, Documentary,Short)
# 1           (5, 1892, Animation,Short)
# 2  (4, 1892, Animation,Comedy,Romance)
# 3          (12, 1892, Animation,Short)
# 4              (1, 1893, Comedy,Short)
# 5                     (1, 1894, Short)
# 6               (1, 1894, Short,Sport)
# 7         (1, 1894, Documentary,Short)
# 8            (40, 1894, Romance,Short)
# 9         (1, 1895, Documentary,Short)

# %%
struct_df.printSchema()
# Out:
# root
#  |-- primaryTitle: string (nullable = true)
#  |-- movie: struct (nullable = false)
#  |    |-- runtimeMinutes: integer (nullable = true)
#  |    |-- startYear: integer (nullable = true)
#  |    |-- genres: string (nullable = true)

# %%
display(
    struct_df
        .select('primaryTitle', 'movie.runtimeMinutes')
)
# Out:
#                                   primaryTitle  runtimeMinutes
# 0                                   Carmencita               1
# 1                       Le clown et ses chiens               5
# 2                               Pauvre Pierrot               4
# 3                                  Un bon bock              12
# 4                             Blacksmith Scene               1
# 5                            Chinese Opium Den               1
# 6  Corbett and Courtney Before the Kinetograph               1
# 7       Edison Kinetoscopic Record of a Sneeze               1
# 8                                   Miss Jerry              40
# 9                          Leaving the Factory               1

# %% [markdown]
# ### Arrays

# %%
array_df = (
    title_basics_sdf
        .selectExpr('primaryTitle','split(genres, ",") as genres_array')
)

display(array_df)
# Out:
#                                   primaryTitle                  genres_array
# 0                                   Carmencita          [Documentary, Short]
# 1                       Le clown et ses chiens            [Animation, Short]
# 2                               Pauvre Pierrot  [Animation, Comedy, Romance]
# 3                                  Un bon bock            [Animation, Short]
# 4                             Blacksmith Scene               [Comedy, Short]
# 5                            Chinese Opium Den                       [Short]
# 6  Corbett and Courtney Before the Kinetograph                [Short, Sport]
# 7       Edison Kinetoscopic Record of a Sneeze          [Documentary, Short]
# 8                                   Miss Jerry              [Romance, Short]
# 9                          Leaving the Factory          [Documentary, Short]

# %%
array_df.printSchema()
# Out:
# root
#  |-- primaryTitle: string (nullable = true)
#  |-- genres_array: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
display(
    array_df
        .selectExpr('primaryTitle', 'genres_array[0]')
)
# Out:
#                                   primaryTitle genres_array[0]
# 0                                   Carmencita     Documentary
# 1                       Le clown et ses chiens       Animation
# 2                               Pauvre Pierrot       Animation
# 3                                  Un bon bock       Animation
# 4                             Blacksmith Scene          Comedy
# 5                            Chinese Opium Den           Short
# 6  Corbett and Courtney Before the Kinetograph           Short
# 7       Edison Kinetoscopic Record of a Sneeze     Documentary
# 8                                   Miss Jerry         Romance
# 9                          Leaving the Factory     Documentary

# %%
# size of array
display(
    title_basics_sdf
        .where('size(split(genres, ",")) >= 3')
)
# Out:
#       tconst titleType                                   primaryTitle  \
# 0  tt0000003     short                                 Pauvre Pierrot
# 1  tt0000020     short                                 The Derby 1895
# 2  tt0000025     short  The Oxford and Cambridge University Boat Race
# 3  tt0000033     short                             Horse Trick Riders
# 4  tt0000038     short                                  The Ball Game
# 5  tt0000041     short                              Bataille de neige
# 6  tt0000131     short                               A Terrible Night
# 7  tt0000138     short                              The Bewitched Inn
# 8  tt0000147     short                  The Corbett-Fitzsimmons Fight
# 9  tt0000152     short                     The Hallucinated Alchemist
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Pauvre Pierrot        0       1892      NaN
# 1                                 The Derby 1895        0       1895      NaN
# 2  The Oxford and Cambridge University Boat Race        0       1895      NaN
# 3                                     La voltige        0       1895      NaN
# 4                                  The Ball Game        0       1898      NaN
# 5                              Bataille de neige        0       1897      NaN
# 6                              Une nuit terrible        0       1896      NaN
# 7                           L'auberge ensorcelée        0       1897      NaN
# 8                  The Corbett-Fitzsimmons Fight        0       1897      NaN
# 9                L'hallucination de l'alchimiste        0       1897      NaN
#
#    runtimeMinutes                    genres
# 0             4.0  Animation,Comedy,Romance
# 1             1.0   Documentary,Short,Sport
# 2             NaN          News,Short,Sport
# 3             1.0  Comedy,Documentary,Short
# 4             NaN   Documentary,Short,Sport
# 5             1.0  Comedy,Documentary,Short
# 6             1.0       Comedy,Horror,Short
# 7             2.0       Comedy,Horror,Short
# 8            20.0    Documentary,News,Short
# 9             2.0      Fantasy,Horror,Short

# %%
# if array contains a value
display(
    title_basics_sdf
        .where('array_contains(split(genres, ","), "Animation")')
)
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000002     short          Le clown et ses chiens
# 1  tt0000003     short                  Pauvre Pierrot
# 2  tt0000004     short                     Un bon bock
# 3  tt0000015     short             Autour d'une cabine
# 4  tt0000233     short   Choque de dos transatlánticos
# 5  tt0000251     short              Matches: An Appeal
# 6  tt0000300     short           The Enchanted Drawing
# 7  tt0000516     short              The Electric Hotel
# 8  tt0000552     short          The Hand of the Artist
# 9  tt0000554     short  Humorous Phases of Funny Faces
#
#                     originalTitle  isAdult  startYear  endYear  \
# 0          Le clown et ses chiens        0       1892      NaN
# 1                  Pauvre Pierrot        0       1892      NaN
# 2                     Un bon bock        0       1892      NaN
# 3             Autour d'une cabine        0       1894      NaN
# 4   Choque de dos transatlánticos        0       1899      NaN
# 5              Matches: An Appeal        0       1899      NaN
# 6           The Enchanted Drawing        0       1900      NaN
# 7              El hotel eléctrico        0       1908      NaN
# 8          The Hand of the Artist        0       1907      NaN
# 9  Humorous Phases of Funny Faces        0       1906      NaN
#
#    runtimeMinutes                    genres
# 0               5           Animation,Short
# 1               4  Animation,Comedy,Romance
# 2              12           Animation,Short
# 3               2           Animation,Short
# 4               2           Animation,Short
# 5               1           Animation,Short
# 6               2  Animation,Comedy,Fantasy
# 7               8  Animation,Fantasy,Sci-Fi
# 8               2           Animation,Short
# 9               3   Animation,Comedy,Family

# %%
# explode
display(
    title_basics_sdf
        .selectExpr('primaryTitle', 'explode(split(genres, ","))')
)
# Out:
#              primaryTitle          col
# 0              Carmencita  Documentary
# 1              Carmencita        Short
# 2  Le clown et ses chiens    Animation
# 3  Le clown et ses chiens        Short
# 4          Pauvre Pierrot    Animation
# 5          Pauvre Pierrot       Comedy
# 6          Pauvre Pierrot      Romance
# 7             Un bon bock    Animation
# 8             Un bon bock        Short
# 9        Blacksmith Scene       Comedy

# %%
# spark.stop()
